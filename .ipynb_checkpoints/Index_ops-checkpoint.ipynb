# %%
import pandas as pd
import requests as req
import json as json

# %%
token = 'f2qbjj68l57'
search = 's&p'
url = f"https://stock-shark.com/api/v1/searchTicker?ticker={search}&token={token}"
print(url)
x = req.get(url)
data = json.loads(x.content)

print(data['data'])
# Out:
# https://stock-shark.com/api/v1/searchTicker?ticker=s&p&token=f2qbjj68l57
# ...

# %%
import pandas as pd
import requests as rq
import json
import os
from dotenv import load_dotenv
from pathlib import Path

# %%
key = "1229a7502b602521282188c7834f7ae1"
request_url = f"https://financialmodelingprep.com/api/v3/historical/sp500_constituent?apikey={key}"

# %%
response = rq.get(request_url).json()

# %%
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "Error Message": "Special Endpoint : This endpoint is not available under your current subscription please visit our subscription page to upgrade your plan at https://site.financialmodelingprep.com/developer/docs/pricing"
# }
